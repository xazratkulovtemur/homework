# %%
#task1

import numpy as np
import matplotlib.pyplot as plt

x=np.linspace(-10,10,10000)
def f_x(x):
    return x**2 - 4*x +4
y=f_x(x)
plt.plot(x,y, label = "$f(x) = x^2 - 4x + 4$")
plt.xlabel("X")
plt.ylabel("Y")
plt.legend()
plt.show()

#task2

# %%
#task2
import numpy as np
import matplotlib.pyplot as plt

x=np.linspace(0,2,10000)
def f_x(x):
    return x**2 - 4*x +4
y=f_x(x)
plt.plot(x,y, label = "$f(x) = x^2 - 4x + 4$", color="black")
plt.xlabel("X")
plt.ylabel("Y")
plt.legend()


thetha=np.linspace(0,2*np.pi,10000)
def sin_x(thetha):
    return np.sin(thetha)
def cos_x(thetha):
    return np.cos(thetha)

y2=sin_x(thetha)
y3=cos_x(thetha)
plt.plot(thetha, y2, label="$g(x) = sin(x)$", color='blue', linestyle="--")
plt.plot(thetha, y3, label="$h(x) = cos(x)$", color = 'red', linestyle="-.")
plt.legend()
plt.show()

# %%
#task3

import matplotlib.pyplot as plt
import numpy as np

fig, axes = plt.subplots(2,2, figsize=(8,8))
x=np.linspace(-2,2,10000)

axes[0,0].plot(x, x**3, label="$y1 = x^3$", color = 'blue')

axes[0,1].plot(x, np.sin(x), label="y2=sinx", color="red", linestyle="--")


axes[1,0].plot(x, np.exp(x), label="$y3=e^x$", color="green", linestyle="-.")


x_pos = x[x > -1]
axes[1,1].plot(x_pos, np.log(x_pos), color = 'black',label ="$ y4 = log (x+1) $", linestyle= ":")

plt.legend()
plt.xlabel("X")
plt.ylabel("Y")
plt.tight_layout()
plt.show()
# Out:
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_29984\1367305172.py:12: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_29984\1367305172.py:15: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_29984\1367305172.py:18: RuntimeWarning: invalid value encountered in log
#   axes[1,1].plot(x_pos, np.log(x_pos), color = 'black',label ="$ y4 = log (x+1) $", linestyle= ":")

# %%
#task4

import numpy as np
import matplotlib.pyplot as plt

x=np.random.uniform(0,10,100)
y=np.random.uniform(0,10,100)

plt.scatter(x,y, color = 'blue', label = "Scatter plot")
plt.xlabel("X values")
plt.ylabel("Y values")
plt.title("Scatter plot")
plt.grid(True)
plt.legend()
plt.show()

# %%
#task5

import numpy as np
import matplotlib.pyplot as plt

x=np.random.normal(0,1,1000)
plt.hist(x,bins =30,  label="Normal distribution", color= 'b', alpha = 0.5, edgecolor = "k")
plt.xlabel("Variable")
plt.ylabel("Frequency")
plt.title("Frequency distribution")
plt.legend()
plt.show()

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
#task6

import numpy as np
import matplotlib.pyplot as plt

fig=plt.figure()
ax=plt.axes(projection='3d')

x=np.linspace(-5,5,1000)
y=np.linspace(-5,5,1000)
xx, yy = np.meshgrid(x,y)
zz=np.cos(xx**2 + yy**2)
ax.plot_surface(xx,yy,zz, cmap="viridis")
label="$f(x,y) = cos(x^2 + y^2)"

ax.legend()
# Out:
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_29984\1377780381.py:16: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   ax.legend()

# %%
#task7

import matplotlib.pyplot as plt

products= ['Product A', 'Product B', 'Product C', 'Product D', 'Product E']
sales = [200,150,250,175,225]
colors= ['g','b','r','k','y']

plt.bar(products, sales, label="Quantity sold of each product", width =0.7, color=colors, edgecolor="k")
plt.xlabel("Products")
plt.ylabel("QUantity")
plt.title("Quantity sold in this month")
plt.legend()
plt.show()

# %%
#task8
import matplotlib.pyplot as plt
import numpy as np

# Product names (x-axis labels)
products = ["A", "B", "C", "D"]

# Data: quantities in different seasons
season_1 = np.array([10, 6, 8, 5])
season_2 = np.array([8, 9, 6, 7])
season_3 = np.array([12, 4, 7, 8])
season_4 = np.array([7, 5, 6, 6])

# Plot each season, stacking them
fig, ax = plt.subplots(figsize=(8, 6))

bar1 = ax.bar(products, season_1, label="Season 1", color='blue')
bar2 = ax.bar(products, season_2, bottom=season_1, label="Season 2", color='red')
bar3 = ax.bar(products, season_3, bottom=season_1 + season_2, label="Season 3", color='green')
bar4 = ax.bar(products, season_4, bottom=season_1 + season_2 + season_3, label="Season 4", color='purple')

# Adding labels for each section
for i, product in enumerate(products):
    total_height = 0  # Track the bottom position
    for season, color in zip([season_1, season_2, season_3, season_4], ['blue', 'red', 'green', 'purple']):
        height = season[i]
        if height > 0:
            ax.text(i, total_height + height / 2, str(height), ha='center', va='center', fontsize=10, color='white')
        total_height += height  # Update bottom position

# Labels and title
ax.set_ylabel("Total Quantity")
ax.set_xlabel("Products")
ax.set_title("Stacked Bar Chart of Product Quantities Over 4 Seasons")
ax.legend()
plt.show()
